# %% [markdown]
# <a href="https://colab.research.google.com/github/Neha-Pal/Machine_Learning-using-Python/blob/main/Machine_Learning(Ridge_and_Lasso_Regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c9b4ef08-2f32-4e0f-80c0-f6555501bedb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9b4ef08-2f32-4e0f-80c0-f6555501bedb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('sample_2.csv')

# %%
data.head()
# Out:
#    Index  Area   Price     place Facilities Near_Highway
# 0      1  1200  340000   kolkata       3BHK          yes
# 1      2  3400  450000      pune       2BHK          yes
# 2      3  5600  123000  hydrabad       1BHK           no
# 3      4  4560  540090    odisha       2BHK          yes
# 4      5  3456  349000    gujrat       3BHK           no

# %%
x=data['Area']
y=data['Price']

# %%
from scipy import stats
slope, intercept, r, p, std_err = stats.linregress(x,y)

# %%
def myfunc(x):
  return slope*x+intercept

mymodel = list(map(myfunc,x))

# %%
from os import replace
features = ['Area']
x=data[features]

#Predicting Value
y=data['Price']
x.head()
x.info()
x.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Area    20 non-null     int64
# dtypes: int64(1)
# memory usage: 288.0 bytes
#    Area
# 0  1200
# 1  3400
# 2  5600
# 3  4560
# 4  3456

# %% [markdown]
# Splitting the dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/4,random_state=4)
y_train.head()
y_test.head()
# Out:
# 19    375488
# 3     540090
# 18    567378
# 6     980000
# 13    679906
# Name: Price, dtype: int64

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
c=reg.intercept_
c
# Out:
# -99319.57842228399

# %%
m=reg.coef_
m
# Out:
# array([211.07733518])

# %%
r_pred_train=m*x_train+c
r_pred_train
# Out:
#             Area
# 4   6.301637e+05
# 0   1.539732e+05
# 17  1.115219e+06
# 12  5.972356e+05
# 11  1.082713e+06
# 15  1.118174e+06
# 10  1.547084e+06
# 9   8.127456e+05
# 2   1.082713e+06
# 16  6.725902e+05
# 7   1.985280e+06
# 8   8.646706e+05
# 1   6.183434e+05
# 5   3.861583e+05
# 14  1.279649e+06

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
mse=cross_val_score(reg,x_train,y_train,scoring='neg_mean_squared_error',cv=5)
mean_mse=np.mean(mse)
print(mean_mse)
# Out:
# -3134544592551.124

# %% [markdown]
# Ridge regression for train dataset

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

ridge=Ridge()
parameters={'alpha':[1e-50,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,45,50,55,100]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(x_train,y_train)

print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 100}
# -3134542999102.6245

# %% [markdown]
# Lasso regression for train dataset

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

lasso=Lasso()
parameters={'alpha':[1e-50,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,45,50,55,100]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)
lasso_regressor.fit(x_train,y_train)

print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.693e+13, tolerance: 3.637e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# ...

# %% [markdown]
# Ridge regression for test dataset

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

ridge=Ridge()
parameters={'alpha':[1e-50,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,45,50,55,100]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(x_test,y_test)

print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 100}
# -111593015395.46786

# %% [markdown]
# Lasso regresion for test dataset

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

lasso=Lasso()
parameters={'alpha':[1e-50,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,45,50,55,100]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)
lasso_regressor.fit(x_test,y_test)

print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.402e+10, tolerance: 1.217e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# ...
